# %% [markdown]
# # Capstone project 2
# ## Image classification model
# ### Cifar-10 data - densenet161 pretrained model - tuning & training

# %%
# %%capture
# TODO: Install any packages that you might need
# For instance, you will need the smdebug package
! pip install smdebug
! pip install torch --no-cache-dir
! pip install torchvision

# %%
# Import packages 
from __future__ import print_function, division
import sagemaker
import boto3
import os
from sagemaker.pytorch import PyTorch
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

plt.ion()   # interactive mode
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Dataset
# #### Folder data will be copy to s3 bucket for training.

# %%
# session and role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = "us-east-1"
# bucket = 'img-ngandn18'
data_bucket = 'cap2-ngandn18'
bucket = sagemaker_session.default_bucket()
os.environ["DEFAULT_S3_BUCKET"] = bucket
# datapath = 'minidogs'
datapath = 'data'
print(sagemaker_session, bucket, region, datapath)
# Out:
# <sagemaker.session.Session object at 0x7f75a286e9d0> sagemaker-us-east-1-503563512855 us-east-1 data

# %%
# Upload data to S3 bucket.
inputs = sagemaker_session.upload_data(path=datapath, bucket=data_bucket, key_prefix=datapath)
print(inputs)
# Out:
# s3://cap2-ngandn18/data

# %% [markdown]
# ## Hyperparameter Tuning
# **TODO:** This is the part where you will finetune a pretrained model with hyperparameter tuning. Remember that you have to tune a minimum of two hyperparameters. However you are encouraged to tune more. You are also encouraged to explain why you chose to tune those particular hyperparameters and the ranges.
#
# **Note:** You will need to use the `hpo.py` script to perform hyperparameter tuning.

# %%
# Declare HP ranges, metrics etc.
from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner,
)

hyperparameter_ranges = {
    "lr": ContinuousParameter(0.0004, 0.001),
    "batch_size": CategoricalParameter([16, 32, 64])
}

# %%
# Create estimators
instance_type='ml.g4dn.4xlarge'
from sagemaker.pytorch import PyTorch

estimator = PyTorch(
    entry_point="hpo.py",
    role=role,
    py_version='py38',
    framework_version="1.9",
    instance_count=1,
    instance_type=instance_type
    )

objective_metric_name = "average test loss"
objective_type = "Minimize"
metric_definitions = [{"Name": "average test loss", 
                       "Regex": "Test set: Average loss: ([0-9\\.]+)"}]

tuner = HyperparameterTuner(
    estimator,
    objective_metric_name,
    hyperparameter_ranges,
    metric_definitions,
    max_jobs=4,
    max_parallel_jobs=2,
    objective_type=objective_type,
)

# %%
# S3 paths for the training job
s3_data_dir = "s3://{}/{}/".format(data_bucket, datapath)
s3_output_dir = "s3://{}/{}/".format(bucket, "output")
s3_model_dir = "s3://{}/{}/".format(bucket, "model")

os.environ['SM_CHANNEL_TRAIN']= s3_data_dir
os.environ['SM_OUTPUT_DATA_DIR']= s3_output_dir
os.environ['SM_MODEL_DIR']= s3_model_dir
print(s3_data_dir)
# Out:
# s3://cap2-ngandn18/data/

# %%
# TODO: Fit your HP Tuner
# tuner.fit() # TODO: Remember to include your data channels
# Fit the HP Tuner with input data channel
tuner.fit({'train' : s3_data_dir}, wait=True)
# Out:
# .................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
# TODO: Get the best estimators and the best HPs
# best_estimator = #TODO
best_estimator = tuner.best_estimator()

#Get the hyperparameters of the best trained model
best_hypers = best_estimator.hyperparameters()
# To know exact data from best_estimator.hyperparameters()
print(best_hypers)

# %% [markdown]
# ## Model Profiling and Debugging
# TODO: Using the best hyperparameters, create and finetune a new model
#
# **Note:** You will need to use the `train_model.py` script to perform model profiling and debugging.

# %%
# TODO: Set up debugging and profiling rules and hooks
# Setting up debugging and profiling rules and hooks
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import (
    Rule,
    DebuggerHookConfig,
    rule_configs,
    ProfilerRule,
    ProfilerConfig, 
    FrameworkProfile
)

rules = [
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
    Rule.sagemaker(rule_configs.vanishing_gradient()),
    Rule.sagemaker(rule_configs.overfit()),
    Rule.sagemaker(rule_configs.overtraining()),
    Rule.sagemaker(rule_configs.poor_weight_initialization()),
    Rule.sagemaker(base_config=rule_configs.class_imbalance(),
                   rule_parameters={"labels_regex": "CrossEntropyLoss_input_1"})
]

profiler_config = ProfilerConfig(
    system_monitor_interval_millis=500, framework_profile_params=FrameworkProfile(num_steps=10)
)
debugger_hook_config = DebuggerHookConfig(
    hook_parameters={"train.save_interval": "100", "eval.save_interval": "10"}
)

# %%
# Since timeout - copy hypers from sagemaker best training job
lr = '0.0008486603267461696'
batch_size = '16'

# %%
# Create and fit an estimator
from time import time
begin = time()
hyperparameters = {'batch_size': batch_size,
                   'lr': lr} # Training with best parameters

instance_type='ml.g4dn.12xlarge'

estimator = PyTorch(
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type=instance_type,
    entry_point="train_model.py",
    framework_version="1.9",
    py_version="py38",
    hyperparameters=hyperparameters,
    profiler_config=profiler_config, # include the profiler hook
    debugger_hook_config=debugger_hook_config, # include the debugger hook
    rules=rules,
)

estimator.fit({'train': s3_data_dir},wait = True)
train_time=time() - begin
print(f'Creating Time: {train_time: .01f} s')
# Out:
# 2022-01-19 11:46:11 Starting - Starting the training job...
# 2022-01-19 11:46:35 Starting - Launching requested ML instancesVanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# ClassImbalance: InProgress
# ProfilerReport: InProgress
# ......
# 2022-01-19 11:47:37 Starting - Preparing the instances for training......
# 2022-01-19 11:48:40 Downloading - Downloading input data................................................
# 2022-01-19 11:56:40 Training - Downloading the training image...
# 2022-01-19 11:57:09 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-01-19 11:57:00,133 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-01-19 11:57:00,172 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-01-19 11:57:00,181 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-01-19 11:57:07,935 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": "16",
#         "lr": "0.0008486603267461696"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2022-01-19-11-46-10-633",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-503563512855/pytorch-training-2022-01-19-11-46-10-633/source/sourcedir.tar.gz",
#     "module_name": "train_model",
#     "network_interface_name": "eth0",
#     "num_cpus": 48,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_model.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":"16","lr":"0.0008486603267461696"}
# SM_USER_ENTRY_POINT=train_model.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_model
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=48
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-503563512855/pytorch-training-2022-01-19-11-46-10-633/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":"16","lr":"0.0008486603267461696"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2022-01-19-11-46-10-633","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-503563512855/pytorch-training-2022-01-19-11-46-10-633/source/sourcedir.tar.gz","module_name":"train_model","network_interface_name":"eth0","num_cpus":48,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_model.py"}
# SM_USER_ARGS=["--batch_size","16","--lr","0.0008486603267461696"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=16
# SM_HP_LR=0.0008486603267461696
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python train_model.py --batch_size 16 --lr 0.0008486603267461696
# [2022-01-19 11:57:10.867 algo-1:26 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-19 11:57:11.005 algo-1:26 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /root/.cache/torch/hub/checkpoints/densenet161-8d451a50.pth
# 0%|          | 0.00/110M [00:00<?, ?B/s]
# 8%|▊         | 8.78M/110M [00:00<00:01, 92.1MB/s]
# 16%|█▋        | 18.1M/110M [00:00<00:01, 95.5MB/s]
# 25%|██▍       | 27.2M/110M [00:00<00:00, 95.5MB/s]
# 33%|███▎      | 36.3M/110M [00:00<00:00, 95.4MB/s]
# 41%|████▏     | 45.6M/110M [00:00<00:00, 96.0MB/s]
# 50%|████▉     | 54.9M/110M [00:00<00:00, 96.4MB/s]
# 58%|█████▊    | 64.2M/110M [00:00<00:00, 96.8MB/s]
# 67%|██████▋   | 73.4M/110M [00:00<00:00, 96.8MB/s]
# 75%|███████▌  | 82.8M/110M [00:00<00:00, 97.3MB/s]
# 84%|████████▎ | 92.3M/110M [00:01<00:00, 97.9MB/s]
# 92%|█████████▏| 102M/110M [00:01<00:00, 97.8MB/s]
# 100%|██████████| 110M/110M [00:01<00:00, 96.8MB/s]
# densenet161
# [2022-01-19 11:57:21.466 algo-1:26 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-01-19 11:57:21.468 algo-1:26 INFO hook.py:200] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-01-19 11:57:21.469 algo-1:26 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2022-01-19 11:57:21.469 algo-1:26 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-01-19 11:57:21.546 algo-1:26 INFO hook.py:591] name:features.conv0.weight count_params:14112
# [2022-01-19 11:57:21.547 algo-1:26 INFO hook.py:591] name:features.norm0.weight count_params:96
# [2022-01-19 11:57:21.547 algo-1:26 INFO hook.py:591] name:features.norm0.bias count_params:96
# [2022-01-19 11:57:21.547 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.norm1.weight count_params:96
# [2022-01-19 11:57:21.548 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.norm1.bias count_params:96
# [2022-01-19 11:57:21.548 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.conv1.weight count_params:18432
# [2022-01-19 11:57:21.548 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.norm2.weight count_params:192
# [2022-01-19 11:57:21.548 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.norm2.bias count_params:192
# [2022-01-19 11:57:21.549 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer1.conv2.weight count_params:82944
# [2022-01-19 11:57:21.549 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer2.norm1.weight count_params:144
# [2022-01-19 11:57:21.549 algo-1:26 INFO hook.py:591] name:features.denseblock1.denselayer2.norm1.bias count_params:144
algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.norm1.weight count_params:2160
# [2022-01-19 11:57:21.677 algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.norm1.bias count_params:2160
# [2022-01-19 11:57:21.677 algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.conv1.weight count_params:414720
# [2022-01-19 11:57:21.677 algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.norm2.weight count_params:192
# [2022-01-19 11:57:21.677 algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.norm2.bias count_params:192
# [2022-01-19 11:57:21.678 algo-1:26 INFO hook.py:591] name:features.denseblock4.denselayer24.conv2.weight count_params:82944
# [2022-01-19 11:57:21.678 algo-1:26 INFO hook.py:591] name:features.norm5.weight count_params:2208
# [2022-01-19 11:57:21.678 algo-1:26 INFO hook.py:591] name:features.norm5.bias count_params:2208
# [2022-01-19 11:57:21.678 algo-1:26 INFO hook.py:591] name:classifier.0.weight count_params:565248
# [2022-01-19 11:57:21.679 algo-1:26 INFO hook.py:591] name:classifier.0.bias count_params:256
# [2022-01-19 11:57:21.679 algo-1:26 INFO hook.py:591] name:classifier.3.weight count_params:2560
# [2022-01-19 11:57:21.679 algo-1:26 INFO hook.py:591] name:classifier.3.bias count_params:10
# [2022-01-19 11:57:21.680 algo-1:26 INFO hook.py:593] Total Trainable Params: 27040074
# Epoch 0/14
# ----------
# [2022-01-19 11:57:22.225 algo-1:26 INFO hook.py:424] Monitoring the collections: losses, gradients, relu_input
# [2022-01-19 11:57:22.226 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/prestepzero-*-start-1642593431006115.0_train-0-stepstart-1642593442226625.2/python_stats.
# [2022-01-19 11:57:22.238 algo-1:26 WARNING hook.py:410] The detailed profiling using autograd profiler is not supported for torch version 1.9.1
# [2022-01-19 11:57:22.239 algo-1:26 INFO hook.py:488] Hook is writing from the hook with pid: 26
# [2022-01-19 11:57:34.078 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-0-stepstart-1642593442237050.8_train-0-forwardpassend-1642593454078038.8/python_stats.
# [2022-01-19 11:57:35.321 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-0-forwardpassend-1642593454080509.8_train-1-stepstart-1642593455320770.5/python_stats.
# [2022-01-19 11:57:35.324 algo-1:26 WARNING hook.py:410] The detailed profiling using autograd profiler is not supported for torch version 1.9.1
# [2022-01-19 11:57:35.467 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-1-stepstart-1642593455324326.0_train-1-forwardpassend-1642593455467160.0/python_stats.
# [2022-01-19 11:57:35.854 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-1-forwardpassend-1642593455468787.8_train-2-stepstart-1642593455854287.2/python_stats.
# [2022-01-19 11:57:35.856 algo-1:26 WARNING hook.py:410] The detailed profiling using autograd profiler is not supported for torch version 1.9.1
# [2022-01-19 11:57:35.997 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-2-stepstart-1642593455856722.8_train-2-forwardpassend-1642593455997537.2/python_stats.
# [2022-01-19 11:57:36.383 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-2-forwardpassend-1642593455998724.5_train-3-stepstart-1642593456383126.0/python_stats.
# [2022-01-19 11:57:36.521 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-3-stepstart-1642593456385624.2_train-3-forwardpassend-1642593456521620.2/python_stats.
# [2022-01-19 11:57:36.901 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-3-forwardpassend-1642593456522718.2_train-4-stepstart-1642593456901079.0/python_stats.
# [2022-01-19 11:57:37.039 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-4-stepstart-1642593456903512.2_train-4-forwardpassend-1642593457038927.0/python_stats.
# [2022-01-19 11:57:37.414 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-4-forwardpassend-1642593457040093.8_train-5-stepstart-1642593457413685.5/python_stats.
# [2022-01-19 11:57:37.550 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-5-stepstart-1642593457416308.2_train-5-forwardpassend-1642593457550137.0/python_stats.
# [2022-01-19 11:57:37.932 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-5-forwardpassend-1642593457551300.2_train-6-stepstart-1642593457932514.2/python_stats.
# [2022-01-19 11:57:38.065 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-6-stepstart-1642593457934744.8_train-6-forwardpassend-1642593458065172.5/python_stats.
# [2022-01-19 11:57:38.449 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-6-forwardpassend-1642593458066200.2_train-7-stepstart-1642593458449576.5/python_stats.
# [2022-01-19 11:57:38.585 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-7-stepstart-1642593458451935.0_train-7-forwardpassend-1642593458584834.2/python_stats.
# [2022-01-19 11:57:38.972 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-7-forwardpassend-1642593458585758.8_train-8-stepstart-1642593458971716.5/python_stats.
# [2022-01-19 11:57:39.104 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-8-stepstart-1642593458973894.2_train-8-forwardpassend-1642593459104616.0/python_stats.
# [2022-01-19 11:57:39.492 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-8-forwardpassend-1642593459105513.8_train-9-stepstart-1642593459492408.0/python_stats.
# [2022-01-19 11:57:39.629 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-9-stepstart-1642593459494734.2_train-9-forwardpassend-1642593459629124.2/python_stats.
# [2022-01-19 11:57:40.023 algo-1:26 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/26-algo-1/train-9-forwardpassend-1642593459630214.2_train-10-stepstart-1642593460022964.0/python_stats.
# train Loss: 0.9527 Acc: 0.6818
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: IssuesFound
# PoorWeightInitialization: InProgress
# ClassImbalance: InProgress
# valid Loss: 0.1850 Acc: 0.9405
# Epoch 1/14
# ----------
# train Loss: 0.5699 Acc: 0.8086
# valid Loss: 0.1500 Acc: 0.9493
# Epoch 2/14
# ----------
# train Loss: 0.5017 Acc: 0.8303
# valid Loss: 0.1413 Acc: 0.9524
# Epoch 3/14
# ----------
# train Loss: 0.4560 Acc: 0.8444
# valid Loss: 0.1228 Acc: 0.9585
# Epoch 4/14
# ----------
# train Loss: 0.4260 Acc: 0.8555
# valid Loss: 0.1185 Acc: 0.9603
# Epoch 5/14
# ----------
# train Loss: 0.3991 Acc: 0.8650
# valid Loss: 0.1011 Acc: 0.9645
# Epoch 6/14
# ----------
# train Loss: 0.3868 Acc: 0.8697
# valid Loss: 0.1146 Acc: 0.9600
# Epoch 7/14
# ----------
# train Loss: 0.3244 Acc: 0.8905
# valid Loss: 0.0897 Acc: 0.9708
# Epoch 8/14
# ----------

# %% [markdown]
# #### Deploy Model: Since timeout problem happens, we get loss connection. Wait until the training job finishes, we will open new notebook to deploy the endpoint.

# %%
# # Deploy your model to an endpoint
# # Add your deployment configuration like instance type and number of instances
# training_job_name = estimator.latest_training_job.name
# print(f'training_job_name = {training_job_name}')
# # No result.
